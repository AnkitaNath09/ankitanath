# %%
#Ankita Nath

# %%
import os

# %%
who=os.chdir("C:\\Users\\Ankita\\Desktop\\python2")

# %%
os.listdir()
# Out:
# ['WHO.csv']

# %%
import pandas as pd

# %%
df=pd.read_csv("WHO.csv");df
# Out:
#                                 Country                 Region  Population  \
# 0                           Afghanistan  Eastern Mediterranean       29825
# 1                               Albania                 Europe        3162
# 2                               Algeria                 Africa       38482
# 3                               Andorra                 Europe          78
# 4                                Angola                 Africa       20821
# ..                                  ...                    ...         ...
# 189  Venezuela (Bolivarian Republic of)               Americas       29955
# 190                            Viet Nam        Western Pacific       90796
# 191                               Yemen  Eastern Mediterranean       23852
# 192                              Zambia                 Africa       14075
# 193                            Zimbabwe                 Africa       13724
#
# ...

# %%
df.head(10)#first 10
# Out:
#                Country                 Region  Population  Under15  Over60  \
# 0          Afghanistan  Eastern Mediterranean       29825    47.42    3.82
# 1              Albania                 Europe        3162    21.33   14.93
# 2              Algeria                 Africa       38482    27.42    7.17
# 3              Andorra                 Europe          78    15.20   22.86
# 4               Angola                 Africa       20821    47.58    3.84
# 5  Antigua and Barbuda               Americas          89    25.96   12.35
# 6            Argentina               Americas       41087    24.42   14.97
# 7              Armenia                 Europe        2969    20.34   14.06
# 8            Australia        Western Pacific       23050    18.95   19.46
# 9              Austria                 Europe        8464    14.51   23.52
#
#    FertilityRate  LifeExpectancy  ChildMortality  CellularSubscribers  \
# 0           5.40              60            98.5                54.26
# ...

# %%
df.tail(15)
# Out:
#                                 Country                 Region  Population  \
# 179                              Tuvalu        Western Pacific          10
# 180                              Uganda                 Africa       36346
# 181                             Ukraine                 Europe       45530
# 182                United Arab Emirates  Eastern Mediterranean        9206
# 183                      United Kingdom                 Europe       62783
# 184         United Republic of Tanzania                 Africa       47783
# 185            United States of America               Americas      318000
# 186                             Uruguay               Americas        3395
# 187                          Uzbekistan                 Europe       28541
# 188                             Vanuatu        Western Pacific         247
# 189  Venezuela (Bolivarian Republic of)               Americas       29955
# ...

# %%
df.dtypes
# Out:
# Country                           object
# Region                            object
# Population                         int64
# Under15                          float64
# Over60                           float64
# FertilityRate                    float64
# LifeExpectancy                     int64
# ChildMortality                   float64
# CellularSubscribers              float64
# LiteracyRate                     float64
# GNI                              float64
# PrimarySchoolEnrollmentMale      float64
# PrimarySchoolEnrollmentFemale    float64
# dtype: object

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 194 entries, 0 to 193
# Data columns (total 13 columns):
#  #   Column                         Non-Null Count  Dtype
# ---  ------                         --------------  -----
#  0   Country                        194 non-null    object
#  1   Region                         194 non-null    object
#  2   Population                     194 non-null    int64
#  3   Under15                        194 non-null    float64
#  4   Over60                         194 non-null    float64
#  5   FertilityRate                  183 non-null    float64
#  6   LifeExpectancy                 194 non-null    int64
#  7   ChildMortality                 194 non-null    float64
#  8   CellularSubscribers            184 non-null    float64
#  9   LiteracyRate                   103 non-null    float64
#  10  GNI                            162 non-null    float64
#  11  PrimarySchoolEnrollmentMale    101 non-null    float64
# ...

# %%
type(df)
# Out:
# pandas.core.frame.DataFrame

# %%
df.describe(include="object")
# Out:
#             Country  Region
# count           194     194
# unique          194       6
# top     New Zealand  Europe
# freq              1      53

# %%
df.describe(include='int64')
# Out:
#          Population  LifeExpectancy
# count  1.940000e+02      194.000000
# mean   3.635997e+04       70.010309
# std    1.379031e+05        9.259075
# min    1.000000e+00       47.000000
# 25%    1.695750e+03       64.000000
# 50%    7.790000e+03       72.500000
# 75%    2.453525e+04       76.000000
# max    1.390000e+06       83.000000

# %%
df.describe(include="float")
# Out:
#           Under15      Over60  FertilityRate  ChildMortality  \
# count  194.000000  194.000000     183.000000      194.000000
# mean    28.732423   11.163660       2.940656       36.148969
# std     10.534573    7.149331       1.480984       37.992935
# min     13.120000    0.810000       1.260000        2.200000
# 25%     18.717500    5.200000       1.835000        8.425000
# 50%     28.650000    8.530000       2.400000       18.600000
# 75%     37.752500   16.687500       3.905000       55.975000
# max     49.990000   31.920000       7.580000      181.600000
#
#        CellularSubscribers  LiteracyRate           GNI  \
# count           184.000000    103.000000    162.000000
# mean             93.641522     83.710680  13320.925926
# std              41.400447     17.530645  15192.988650
# min               2.570000     31.100000    340.000000
# 25%              63.567500     71.600000   2335.000000
# 50%              97.745000     91.800000   7870.000000
# ...

# %%
import numpy as np

# %%
df.describe(include=np.number)
# Out:
#          Population     Under15      Over60  FertilityRate  LifeExpectancy  \
# count  1.940000e+02  194.000000  194.000000     183.000000      194.000000
# mean   3.635997e+04   28.732423   11.163660       2.940656       70.010309
# std    1.379031e+05   10.534573    7.149331       1.480984        9.259075
# min    1.000000e+00   13.120000    0.810000       1.260000       47.000000
# 25%    1.695750e+03   18.717500    5.200000       1.835000       64.000000
# 50%    7.790000e+03   28.650000    8.530000       2.400000       72.500000
# 75%    2.453525e+04   37.752500   16.687500       3.905000       76.000000
# max    1.390000e+06   49.990000   31.920000       7.580000       83.000000
#
#        ChildMortality  CellularSubscribers  LiteracyRate           GNI  \
# count      194.000000           184.000000    103.000000    162.000000
# mean        36.148969            93.641522     83.710680  13320.925926
# std         37.992935            41.400447     17.530645  15192.988650
# ...

# %%
df.describe(include="all")
# Out:
#             Country  Region    Population     Under15      Over60  \
# count           194     194  1.940000e+02  194.000000  194.000000
# unique          194       6           NaN         NaN         NaN
# top     New Zealand  Europe           NaN         NaN         NaN
# freq              1      53           NaN         NaN         NaN
# mean            NaN     NaN  3.635997e+04   28.732423   11.163660
# std             NaN     NaN  1.379031e+05   10.534573    7.149331
# min             NaN     NaN  1.000000e+00   13.120000    0.810000
# 25%             NaN     NaN  1.695750e+03   18.717500    5.200000
# 50%             NaN     NaN  7.790000e+03   28.650000    8.530000
# 75%             NaN     NaN  2.453525e+04   37.752500   16.687500
# max             NaN     NaN  1.390000e+06   49.990000   31.920000
#
#         FertilityRate  LifeExpectancy  ChildMortality  CellularSubscribers  \
# count      183.000000      194.000000      194.000000           184.000000
# ...

# %%
df['Region']
# Out:
# 0      Eastern Mediterranean
# 1                     Europe
# 2                     Africa
# 3                     Europe
# 4                     Africa
#                ...
# 189                 Americas
# 190          Western Pacific
# 191    Eastern Mediterranean
# 192                   Africa
# 193                   Africa
# Name: Region, Length: 194, dtype: object

# %%
df.Region.describe()
# Out:
# count        194
# unique         6
# top       Europe
# freq          53
# Name: Region, dtype: object

# %%
df.loc[0,:] #zero row and all col
# Out:
# Country                                    Afghanistan
# Region                           Eastern Mediterranean
# Population                                       29825
# Under15                                          47.42
# Over60                                            3.82
# FertilityRate                                      5.4
# LifeExpectancy                                      60
# ChildMortality                                    98.5
# CellularSubscribers                              54.26
# LiteracyRate                                       NaN
# GNI                                             1140.0
# PrimarySchoolEnrollmentMale                        NaN
# PrimarySchoolEnrollmentFemale                      NaN
# Name: 0, dtype: object

# %%
df.loc[0:5,] #very fast rows and all col
# Out:
#                Country                 Region  Population  Under15  Over60  \
# 0          Afghanistan  Eastern Mediterranean       29825    47.42    3.82
# 1              Albania                 Europe        3162    21.33   14.93
# 2              Algeria                 Africa       38482    27.42    7.17
# 3              Andorra                 Europe          78    15.20   22.86
# 4               Angola                 Africa       20821    47.58    3.84
# 5  Antigua and Barbuda               Americas          89    25.96   12.35
#
#    FertilityRate  LifeExpectancy  ChildMortality  CellularSubscribers  \
# 0           5.40              60            98.5                54.26
# 1           1.75              74            16.7                96.39
# 2           2.83              73            20.0                98.99
# 3            NaN              82             3.2                75.49
# 4           6.10              51           163.5                48.38
# ...

# %%
df.loc[[7,8,4],] #take out 7th,8th,4th row and all col
# Out:
#      Country           Region  Population  Under15  Over60  FertilityRate  \
# 7    Armenia           Europe        2969    20.34   14.06           1.74
# 8  Australia  Western Pacific       23050    18.95   19.46           1.89
# 4     Angola           Africa       20821    47.58    3.84           6.10
#
#    LifeExpectancy  ChildMortality  CellularSubscribers  LiteracyRate      GNI  \
# 7              71            16.4               103.57          99.6   6100.0
# 8              82             4.9               108.34           NaN  38110.0
# 4              51           163.5                48.38          70.1   5230.0
#
#    PrimarySchoolEnrollmentMale  PrimarySchoolEnrollmentFemale
# 7                          NaN                            NaN
# 8                         96.9                           97.5
# 4                         93.1                           78.2

# %%
df.loc[:,['Population']] #all rows and polulation col
# Out:
#      Population
# 0         29825
# 1          3162
# 2         38482
# 3            78
# 4         20821
# ..          ...
# 189       29955
# 190       90796
# 191       23852
# 192       14075
# 193       13724
#
# [194 rows x 1 columns]

# %%
df.loc[0:12,['Population','GNI']] #take out 0 to 12 rows and these cols
# Out:
#     Population      GNI
# 0        29825   1140.0
# 1         3162   8820.0
# 2        38482   8310.0
# 3           78      NaN
# 4        20821   5230.0
# 5           89  17900.0
# 6        41087  17130.0
# 7         2969   6100.0
# 8        23050  38110.0
# 9         8464  42050.0
# 10        9309   8960.0
# 11         372      NaN
# 12        1318      NaN

# %%
df["GNI"].iloc[20:30]
# Out:
# 20     4890.0
# 21     9190.0
# 22    14550.0
# 23    11420.0
# 24        NaN
# 25    14160.0
# 26     1300.0
# 27      610.0
# 28     2230.0
# 29     2330.0
# Name: GNI, dtype: float64

# %%
df.loc[60:67]
# Out:
#     Country  Region  Population  Under15  Over60  FertilityRate  \
# 60  Finland  Europe        5408    16.42   25.90           1.85
# 61   France  Europe       63937    18.26   23.82           1.98
# 62    Gabon  Africa        1633    38.49    7.38           4.18
# 63   Gambia  Africa        1791    45.90    3.72           5.79
# 64  Georgia  Europe        4358    17.62   19.47           1.82
# 65  Germany  Europe       82800    13.17   26.72           1.40
# 66    Ghana  Africa       25366    38.59    5.40           3.99
# 67   Greece  Europe       11125    14.60   25.41           1.51
#
#     LifeExpectancy  ChildMortality  CellularSubscribers  LiteracyRate  \
# 60              81             2.9               166.02           NaN
# 61              82             4.1                94.79           NaN
# 62              62            62.0               117.32          88.4
# 63              58            72.9                78.89          50.0
# ...

# %%
df.iloc[90:100,0:3] #taking out rows of 90 to 100, col 0 to 3
# Out:
#                              Country                 Region  Population
# 90                            Kuwait  Eastern Mediterranean        3250
# 91                        Kyrgyzstan                 Europe        5474
# 92  Lao People's Democratic Republic        Western Pacific        6646
# 93                            Latvia                 Europe        2060
# 94                           Lebanon  Eastern Mediterranean        4647
# 95                           Lesotho                 Africa        2052
# 96                           Liberia                 Africa        4190
# 97                             Libya  Eastern Mediterranean        6155
# 98                         Lithuania                 Europe        3028
# 99                        Luxembourg                 Europe         524

# %%
df[["Population","Under15","FertilityRate"]]
# Out:
#      Population  Under15  FertilityRate
# 0         29825    47.42           5.40
# 1          3162    21.33           1.75
# 2         38482    27.42           2.83
# 3            78    15.20            NaN
# 4         20821    47.58           6.10
# ..          ...      ...            ...
# 189       29955    28.84           2.44
# 190       90796    22.87           1.79
# 191       23852    40.72           4.35
# 192       14075    46.73           5.77
# 193       13724    40.24           3.64
#
# [194 rows x 3 columns]

# %%
df[["Population","Under15","FertilityRate"]].iloc[45:80]
# Out:
#     Population  Under15  FertilityRate
# 45       10660    14.56           1.53
# 46       24763    21.98           2.00
# 47       65705    45.11           6.15
# 48        5598    17.66           1.88
# 49         860    33.72           3.53
# 50          72    25.96            NaN
# 51       10277    30.53           2.55
# 52       15492    30.29           2.62
# 53       80722    31.25           2.85
# 54        6297    30.62           2.24
# 55         736    38.95           5.04
# 56        6131    43.10           4.88
# 57        1291    15.69           1.62
# 58       91729    43.29           4.77
# 59         875    28.88           2.64
# 60        5408    16.42           1.85
# 61       63937    18.26           1.98
# 62        1633    38.49           4.18
# 63        1791    45.90           5.79
# 64        4358    17.62           1.82
# 65       82800    13.17           1.40
# 66       25366    38.59           3.99
# 67       11125    14.60           1.51
# ...

# %%
df[df['Over60']>25]
# Out:
#         Country           Region  Population  Under15  Over60  FertilityRate  \
# 25     Bulgaria           Europe        7278    13.53   26.11           1.51
# 60      Finland           Europe        5408    16.42   25.90           1.85
# 65      Germany           Europe       82800    13.17   26.72           1.40
# 67       Greece           Europe       11125    14.60   25.41           1.51
# 83        Italy           Europe       60885    14.04   26.97           1.45
# 85        Japan  Western Pacific      127000    13.12   31.92           1.39
# 147  San Marino           Europe          31    14.04   26.97            NaN
# 166      Sweden           Europe        9511    16.71   25.32           1.93
#
#      LifeExpectancy  ChildMortality  CellularSubscribers  LiteracyRate  \
# 25               74            12.1               140.68           NaN
# 60               81             2.9               166.02           NaN
# ...

# %%
df["FertilityRate"]+45
# Out:
# 0      50.40
# 1      46.75
# 2      47.83
# 3        NaN
# 4      51.10
#        ...
# 189    47.44
# 190    46.79
# 191    49.35
# 192    50.77
# 193    48.64
# Name: FertilityRate, Length: 194, dtype: float64

# %%
df['GNI'].max()
# Out:
# 86440.0

# %%
df['GNI'].min()
# Out:
# 340.0

# %%
df['GNI'].median()
# Out:
# 7870.0

# %%
df.loc[df['GNI']==340.0]
# Out:
#                              Country  Region  Population  Under15  Over60  \
# 47  Democratic Republic of the Congo  Africa       65705    45.11    4.51
#
#     FertilityRate  LifeExpectancy  ChildMortality  CellularSubscribers  \
# 47           6.15              49           145.7                23.09
#
#     LiteracyRate    GNI  PrimarySchoolEnrollmentMale  \
# 47          66.8  340.0                          NaN
#
#     PrimarySchoolEnrollmentFemale
# 47                            NaN

# %%
df_no_na=df.notna()
df_no_na
# Out:
#      Country  Region  Population  Under15  Over60  FertilityRate  \
# 0       True    True        True     True    True           True
# 1       True    True        True     True    True           True
# 2       True    True        True     True    True           True
# 3       True    True        True     True    True          False
# 4       True    True        True     True    True           True
# ..       ...     ...         ...      ...     ...            ...
# 189     True    True        True     True    True           True
# 190     True    True        True     True    True           True
# 191     True    True        True     True    True           True
# 192     True    True        True     True    True           True
# 193     True    True        True     True    True           True
#
#      LifeExpectancy  ChildMortality  CellularSubscribers  LiteracyRate    GNI  \
# 0              True            True                 True         False   True
# ...

# %%
df_no_na.shape
# Out:
# (194, 13)

# %%
df_Country_no_na=df['Country'].notna()
df_Country_no_na
# Out:
# 0      True
# 1      True
# 2      True
# 3      True
# 4      True
#        ...
# 189    True
# 190    True
# 191    True
# 192    True
# 193    True
# Name: Country, Length: 194, dtype: bool

# %%
df.isnull().sum()
# Out:
# Country                           0
# Region                            0
# Population                        0
# Under15                           0
# Over60                            0
# FertilityRate                    11
# LifeExpectancy                    0
# ChildMortality                    0
# CellularSubscribers              10
# LiteracyRate                     91
# GNI                              32
# PrimarySchoolEnrollmentMale      93
# PrimarySchoolEnrollmentFemale    93
# dtype: int64

# %%
df.dropna(subset=["Region"],axis=0,inplace=True);df1

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 194 entries, 0 to 193
# Data columns (total 13 columns):
#  #   Column                         Non-Null Count  Dtype
# ---  ------                         --------------  -----
#  0   Country                        194 non-null    object
#  1   Region                         194 non-null    object
#  2   Population                     194 non-null    int64
#  3   Under15                        194 non-null    float64
#  4   Over60                         194 non-null    float64
#  5   FertilityRate                  183 non-null    float64
#  6   LifeExpectancy                 194 non-null    int64
#  7   ChildMortality                 194 non-null    float64
#  8   CellularSubscribers            184 non-null    float64
#  9   LiteracyRate                   103 non-null    float64
#  10  GNI                            162 non-null    float64
#  11  PrimarySchoolEnrollmentMale    101 non-null    float64
# ...

# %%
df.corr() #correlation
# Out:
#                                Population   Under15    Over60  FertilityRate  \
# Population                       1.000000 -0.059634  0.011693      -0.075156
# Under15                         -0.059634  1.000000 -0.829390       0.936096
# Over60                           0.011693 -0.829390  1.000000      -0.699413
# FertilityRate                   -0.075156  0.936096 -0.699413       1.000000
# LifeExpectancy                   0.016277 -0.836467  0.688129      -0.839840
# ChildMortality                  -0.003675  0.815076 -0.624303       0.864038
# CellularSubscribers             -0.056345 -0.613113  0.439898      -0.621337
# LiteracyRate                     0.035232 -0.769803  0.596493      -0.802261
# GNI                             -0.033255 -0.685432  0.622878      -0.548732
# PrimarySchoolEnrollmentMale     -0.024105 -0.562826  0.460950      -0.633958
# PrimarySchoolEnrollmentFemale   -0.076504 -0.626167  0.508001      -0.702626
#
# ...
